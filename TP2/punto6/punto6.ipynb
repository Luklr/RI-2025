# %% [markdown]
# # Graficas normales y sin interpolar

# %%
import matplotlib.pyplot as plt

# %%
recall = [0.091, 0.091, 0.091, 0.182, 0.273, 0.273, 0.273, 0.273 ,0.273, 0.364, 0.364, 0.364, 0.364, 0.455, 0.455]
precision = [1.0, 0.5, 0.333, 0.5, 0.6, 0.5, 0.428, 0.375, 0.333, 0.4, 0.364, 0.333, 0.308, 0.357, 0.333]

plt.plot(recall, precision, label='Sin interpolar', marker='o')
plt.plot(recall, interp_precision, label='Interpolada', marker='x', linestyle='--')
plt.xlabel('Recall')
plt.ylabel('Precisión')
plt.title('Curva Precisión vs Recall')
plt.legend()
plt.grid()
plt.show()
